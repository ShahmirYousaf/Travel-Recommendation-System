# %%
import pandas as pd
import os

folder_path = r'D:\Datasets'

# Specify the file name
file_name = 'yelp_academic_dataset_user.csv'

file_path = os.path.join(folder_path, file_name)

df_users = pd.read_csv(file_path, nrows = 10000)

# %%
df_users.head(5)
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7                                                NaN
#
#                                              friends  fans  ...  \
# ...

# %%
file_name_review = 'yelp_academic_dataset_review.csv'

file_path_review = os.path.join(folder_path, file_name_review)

df_review = pd.read_csv(file_path_review, nrows = 10000)

# %%
df_review.head(5)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# ...

# %%
file_name_business = 'yelp_dataset_dataset_business_clean_withoriginalfeature.csv'

file_path_business = os.path.join(folder_path, file_name_business)
# load  the datasett
df_business = pd.read_csv(file_path_business, nrows = 10000)
# create new binary columns based on the level of restaurants price
df_dummies = pd.get_dummies(df_business['RestaurantsPriceRange2'], prefix='PriceRange')

# Concatenate the dummy variables with the original DataFrame
df_business = pd.concat([df_business, df_dummies], axis=1)

# %%
df_business.head(5)
# Out:
#               business_id                      name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 2  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 3  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 4  n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
#
#                                       address          city state postal_code  \
# 0             87 Grasso Plaza Shopping Center        Affton    MO       63123
# 1                                 935 Race St  Philadelphia    PA       19107
# 2                               101 Walnut St    Green Lane    PA       18054
# 3                               615 S Main St  Ashland City    TN       37015
# 4  8522 Eager Road, Dierbergs Brentwood Point     Brentwood    MO       63144
#
#     latitude  longitude  stars  review_count  ...  name_encoded  \
# 0  38.551126 -90.335695    3.0            15  ...         81906
# ...

# %%
df_sorted = df_users.sort_values(by='review_count', ascending=False)
df_sorted
# Out:
#                      user_id      name  review_count        yelping_since  \
# 4723  hWDybu_KvYLSdEFzGrniTw     Bruce         16567  2009-03-08 21:47:44
# 152   P5bUL3Engv-2z6kKohB6qQ       Kim          9941  2006-05-31 21:27:42
# 3977  nmdkHL2JKFx55T3nq5VziA    Nijole          8363  2011-11-29 15:50:53
# 7394  8RcEwGrFIgkt9WQ35E6SnQ    George          7738  2009-11-06 22:53:16
# 1229  CxDOIDnH8gp9KXzpBHJYXw  Jennifer          6679  2009-11-09 20:44:45
# ...                      ...       ...           ...                  ...
# 7052  V0gWGxp9euylW-fZyZjNug      Mark             1  2010-07-02 02:31:20
# 2256  m8AwooeN_3mgTj5Q8eGhmg   William             1  2011-10-31 00:21:38
# 9973  tkBYtqaQzxT9CXxFNHBRQw      Tina             1  2011-07-09 14:38:24
# 3982  KY2LdCTYwfxaj6dHzVgDLQ     Nikki             1  2010-07-12 21:29:57
# 8228  tPKcJdtMZsryLHvhnvF6GQ     Chris             1  2009-05-27 22:08:58
#
#       useful  funny    cool  \
# 4723  173089  98459  144849
# ...

# %%
# get users historical perference
filtered_review = df_review[df_review['user_id'] == 'OyoGAe7OKpv6SyGZT5g77Q']

# %%
filtered_review
# Out:
#                 review_id                 user_id             business_id  \
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
#
#    stars  useful  funny  cool  \
# 1    5.0       1      0     1
#
#                                                 text                 date
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
